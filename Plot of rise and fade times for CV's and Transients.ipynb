# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# plot of points with red filter
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
red_trans_rise = [0.75, 4.13]
red_trans_fade = [2.34, 3.43]
ax1.scatter([red_trans_rise], [red_trans_fade], c='red')
red_cv_rise = [0.8, 51.68, 124.51, 2.94, 0.45, 162.0, 0.67, 2.36, 0.34, 0.87]
red_cv_fade = [6.63, 8.59, 6.6, 5.31, 4.2, 3.67, 4.26, 2.51, 2.25, 3.25]
ax1.scatter([red_cv_rise], [red_cv_fade], c='#99250C', marker='v')

# plot of points with green filter
ax2 = plt.subplot(2,1,2)
green_trans_rise = [2.2, 1.81]
green_trans_fade = [3.0, 5.22]
ax2.scatter([green_trans_rise], [green_trans_fade], c='#1DE71D')
green_cv_rise = [0.57, 10.38, 100.92, 0.78, 0.53, 194.07, 0.61, 1.74, 0.37, 0.69]
green_cv_fade = [4.44, 8.4, 8.88, 3.07, 3.89, 5.12, 6.23, 3.59, 2.28, 3.07]
ax2.scatter([green_cv_rise], [green_cv_fade], c='#146A14', marker='v')

# plot formatting
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.xlabel("Rise Time")
plt.ylabel("Fade Time")
plt.axis([0, 5, 0, 8])

ax1.text(0.85, 2.1, 'ZTF18abcfcoo')
ax1.text(3.7, 2.2, 'ZTF20abfhyil')

ax2.text(2.3, 2.75, 'ZTF18abvkwla')
ax2.text(1.9, 5.05, 'ZTF20abfhyil')
# Out:
# Text(1.9, 5.05, 'ZTF20abfhyil')
