# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# %%
def find_derivative(x_vals, y_vals):
    slope = []
    for i in range(len(y_vals)-1):
        values = (y_vals[i+1]-y_vals[i])/(x_vals[i+1]-x_vals[i])
        slope.append(values)

    time = []
    for i in range(len(x_vals)-1):
        xvalues = (x_vals[i]+x_vals[i+1])/2
        time.append(xvalues)

    return slope, time


def include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals):
    y_vals = np.array(y_vals)
    x_vals = np.array(x_vals)
    nd_y_vals = np.array(nd_y_vals)
    nd_x_vals = np.array(nd_x_vals)

    nd_x_before_peak = nd_x_vals[nd_x_vals<x_vals[0]][-1]
    nd_y_before_peak = nd_y_vals[nd_x_vals<x_vals[0]][-1]
    x_vals = np.append(x_vals, nd_x_before_peak)
    y_vals = np.append(y_vals, nd_y_before_peak)
    
    order = np.argsort(x_vals)
    
    return x_vals[order], y_vals[order]

# %%
CV_1 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF19abppewc_20220603\\detections_ZTF19abppewc.csv")
plotname = CV_1

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_1

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF19abppewc')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_4 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF20abzcokk_20220606\\detections_ZTF20abzcokk.csv")
plotname = CV_4

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_4

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF20abzcokk')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_5 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF21acaohjl_20220606\\detections_ZTF21acaohjl.csv")
plotname = CV_5

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_5

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF21acaohjl')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_7 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF20aawbodq_20220606\\detections_ZTF20aawbodq.csv")
plotname = CV_7

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_7

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF20aawbodq')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 1
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_8 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF19achbhfc_20220606\\detections_ZTF19achbhfc.csv")
plotname = CV_8

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_8

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF19achbhfc')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_9 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF19abzipjc_20220606\\detections_ZTF19abzipjc.csv")
plotname = CV_9

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_9

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF19abzipjc')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_10 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF19abyrano_20220606\\detections_ZTF19abyrano.csv")
plotname = CV_10

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_10

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF19abyrano')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()
# Out:
# [-5.139951022158674, -4.438709646615276, -1.086010265963007, 1.183429406419623, 1.6722580503990825, 0.2703712360086927, 0.7832562130859492, 3.3405505590045115, 0.15656985337450458, 0.21342378076743856, 0.2850175081587245, -2.474481893702397, 0.20159823766850327, -0.0696482144555497, 2.113598133418201, 0.1917303958944705, -0.2636442449345306, 1.0928961705385605, 0.11510778493766662, -1.7870077010954326, 5.443860166146005, -0.029045744436848753, 9.734193473522225, 0.06333081650029056, 1.1184213406057055, -8.794630704215333, 0.22462521074125927, 2.7790143781962326, -7.764630567293584, 0.19924112650150447, 0.1334688797546588, 1.009196063015786, -4.3870762234756935, -105.00665884911218, 0.18627276830335265, 0.02930617451428104, -0.08248188239898968, 0.022235860215550622, -3.590562662089133, 0.8545507403183534, 0.05405077994353081, -3.011266772850341, 8.678076780023765, 0.1042705638426798, -2.950772532766574, 0.612523530744915, 2.103091401259761, 1.917545079748503]

# %%
CV_11 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF22aahnvmo_20220616\\detections_ZTF22aahnvmo.csv")
plotname = CV_11

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_11

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF22aahnvmo')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_12 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF22aakzsrj_20220616\\detections_ZTF22aakzsrj.csv")
plotname = CV_12

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_12

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF22aakzsrj')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_13 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF21accyuff_20220616\\detections_ZTF21accyuff.csv")
plotname = CV_13

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_13

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 10
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF21accyuff')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 12
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_14 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF21aazmjby_20220616\\detections_ZTF21aazmjby.csv")
plotname = CV_14

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_14

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF21aazmjby')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_15 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF18absnibc_20220616\\detections_ZTF18absnibc.csv")
plotname = CV_15

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_15

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

# defining start and end
start = 0
finish = 8
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF18absnibc')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_18 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF20aavtaib_20220616\\detections_ZTF20aavtaib.csv")
ND_18 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF20aavtaib_20220616\\non_detections_ZTF20aavtaib.csv")
plotname = CV_18
non_detection = ND_18

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')

nd_red_points = non_detection['fid']==2
nd_green_points = non_detection['fid']==1
plt.errorbar(non_detection['mjd'][nd_red_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_red_points], c='red', fmt='v')
plt.errorbar(non_detection['mjd'][nd_green_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_green_points], c='green', fmt='v')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_18

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

nd_x_vals = non_detection['mjd'][nd_red_points]-plotname['mjd'][0]
nd_y_vals = non_detection['diffmaglim'][nd_red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF20aavtaib')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

nd_x_vals = non_detection['mjd'][nd_green_points]-plotname['mjd'][0]
nd_y_vals = non_detection['diffmaglim'][nd_green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()
# Out:
# C:\Users\marya\AppData\Local\Temp\ipykernel_22128\2512273786.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   values = (y_vals[i+1]-y_vals[i])/(x_vals[i+1]-x_vals[i])

# %%
CV_19= pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF21acgrero_20220616\\detections_ZTF21acgrero.csv")
ND_19 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF21acgrero_20220616\\non_detections_ZTF21acgrero.csv")
plotname = CV_19
non_detection = ND_19

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')

nd_red_points = non_detection['fid']==2
nd_green_points = non_detection['fid']==1
plt.errorbar(non_detection['mjd'][nd_red_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_red_points], c='red', fmt='v')
plt.errorbar(non_detection['mjd'][nd_green_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_green_points], c='green', fmt='v')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_19

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

nd_x_vals = non_detection['mjd'][nd_red_points]-plotname['mjd'][0]
nd_y_vals = non_detection['diffmaglim'][nd_red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF21acgrero')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

nd_x_vals = non_detection['mjd'][nd_green_points]-plotname['mjd'][0]
nd_y_vals = non_detection['diffmaglim'][nd_green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
CV_20= pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF18abrxrms_20220616\\detections_ZTF18abrxrms.csv")
ND_20 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF18abrxrms_20220616\\non_detections_ZTF18abrxrms.csv")
plotname = CV_20
non_detection = ND_20

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')

nd_red_points = non_detection['fid']==2
nd_green_points = non_detection['fid']==1
plt.errorbar(non_detection['mjd'][nd_red_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_red_points], c='red', fmt='v')
plt.errorbar(non_detection['mjd'][nd_green_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_green_points], c='green', fmt='v')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = CV_20

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

#nd_x_vals = non_detection['mjd'][nd_red_points]-plotname['mjd'][0]
#nd_y_vals = non_detection['diffmaglim'][nd_red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
#x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF18abrxrms')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

#nd_x_vals = non_detection['mjd'][nd_green_points]-plotname['mjd'][0]
#nd_y_vals = non_detection['diffmaglim'][nd_green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
#x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
abv_detections = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF18abvkwla detections - Sheet1.csv")
abv_nd = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF18abvkwla non detections - Sheet1.csv")
plotname = abv_detections
non_detection = abv_nd

# %%
red_points = plotname['Filter']=='r'
green_points = plotname['Filter']=='g'
plt.errorbar(plotname['Date'][red_points]-plotname['Date'][0], plotname['Mag'][red_points], plotname['Mag_err'][red_points], c='red', fmt='o')
plt.errorbar(plotname['Date'][green_points]-plotname['Date'][0], plotname['Mag'][green_points], plotname['Mag_err'][green_points], c='green', fmt='o')

nd_red_points = non_detection['Filter']=='r'
nd_green_points = non_detection['Filter']=='g'
plt.errorbar(non_detection['Date'][nd_red_points]-plotname['Date'][0], non_detection['Mag'][nd_red_points], c='red', fmt='v')
plt.errorbar(non_detection['Date'][nd_green_points]-plotname['Date'][0], non_detection['Mag'][nd_green_points], c='green', fmt='v')
plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = abv_detections

red_points = plotname['Filter']=='r'
x_vals = plotname['Date'][red_points]-plotname['Date'][0]
y_vals = plotname['Mag'][red_points]

nd_x_vals = non_detection['Date'][nd_red_points]-plotname['Date'][0]
nd_y_vals = non_detection['Mag'][nd_red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF18abvkwla')


# plot for green filter


green_points = plotname['Filter']=='g'
x_vals = plotname['Date'][green_points]-plotname['Date'][0]
y_vals = plotname['Mag'][green_points]

nd_x_vals = non_detection['Date'][nd_green_points]-plotname['Date'][0]
nd_y_vals = non_detection['Mag'][nd_green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()
# Out:
# C:\Users\marya\AppData\Local\Temp\ipykernel_22128\2512273786.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   values = (y_vals[i+1]-y_vals[i])/(x_vals[i+1]-x_vals[i])

# %%
abc_detections = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF18abcfcoo detections - Sheet1.csv")
abc_nd = pd.read_csv('C:\\Users\\marya\\Downloads\\ZTF18abcfcoo non detections - Sheet1.csv')
plotname = abc_detections
non_detection = abc_nd

# %%
red_points = plotname['Filter']=='r'
green_points = plotname['Filter']=='g'
plt.errorbar(plotname['Date'][red_points]-plotname['Date'][0], plotname['Mag'][red_points], plotname['Mag_err'][red_points], c='red', fmt='o')
plt.errorbar(plotname['Date'][green_points]-plotname['Date'][0], plotname['Mag'][green_points], plotname['Mag_err'][green_points], c='green', fmt='o')

nd_red_points = non_detection['Filter']=='r'
nd_green_points = non_detection['Filter']=='g'
plt.errorbar(non_detection['Date'][nd_red_points]-plotname['Date'][0], non_detection['Mag'][nd_red_points], c='red', fmt='v')
plt.errorbar(non_detection['Date'][nd_green_points]-plotname['Date'][0], non_detection['Mag'][nd_green_points], c='green', fmt='v')

plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = abc_detections

red_points = plotname['Filter']=='r'
x_vals = plotname['Date'][red_points]-plotname['Date'][0]
y_vals = plotname['Mag'][red_points]

#nd_x_vals = non_detection['Date'][nd_red_points]-plotname['Date'][0]
#nd_y_vals = non_detection['Mag'][nd_red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
#x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF18abcfcoo')


# plot for green filter


green_points = plotname['Filter']=='g'
x_vals = plotname['Date'][green_points]-plotname['Date'][0]
y_vals = plotname['Mag'][green_points]

nd_x_vals = non_detection['Date'][nd_green_points]-plotname['Date'][0]
nd_y_vals = non_detection['Mag'][nd_green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()

# %%
aci_detections = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF20acigmel detections - Sheet1.csv")
plotname = aci_detections

# %%
red_points = plotname['Filter']=='r'
green_points = plotname['Filter']=='g'
plt.errorbar(plotname['Date'][red_points]-plotname['Date'][0], plotname['Mag'][red_points], plotname['Mag_err'][red_points], c='red', fmt='o')
plt.errorbar(plotname['Date'][green_points]-plotname['Date'][0], plotname['Mag'][green_points], plotname['Mag_err'][green_points], c='green', fmt='o')

plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = aci_detections

red_points = plotname['Filter']=='r'
x_vals = plotname['Date'][red_points]-plotname['Date'][0]
y_vals = plotname['Mag'][red_points]

#nd_x_vals = non_detection['Date'][nd_red_points]-plotname['Date'][0]
#nd_y_vals = non_detection['Mag'][nd_red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
#x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF20acigmel')


# plot for green filter


green_points = plotname['Filter']=='g'
x_vals = plotname['Date'][green_points]-plotname['Date'][0]
y_vals = plotname['Mag'][green_points]

#nd_x_vals = non_detection['Date'][nd_green_points]-plotname['Date'][0]
#nd_y_vals = non_detection['Mag'][nd_green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
#x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_vals, y_vals)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()
# Out:
# C:\Users\marya\AppData\Local\Temp\ipykernel_22128\2512273786.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   values = (y_vals[i+1]-y_vals[i])/(x_vals[i+1]-x_vals[i])
# C:\Users\marya\AppData\Local\Temp\ipykernel_22128\2512273786.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   values = (y_vals[i+1]-y_vals[i])/(x_vals[i+1]-x_vals[i])

# %%
ET_4 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF20abfhyil_20220606\\detections_ZTF20abfhyil.csv")
ND_4 = pd.read_csv("C:\\Users\\marya\\Downloads\\ZTF20abfhyil_20220606\\non_detections_ZTF20abfhyil.csv")

non_detection = ND_4
non_detection

plotname = ET_4

# %%
red_points = plotname['fid']==2
green_points = plotname['fid']==1
plt.errorbar(plotname['mjd'][red_points]-plotname['mjd'][0], plotname['magpsf'][red_points], plotname['sigmapsf'][red_points], c='red', fmt='o')
plt.errorbar(plotname['mjd'][green_points]-plotname['mjd'][0], plotname['magpsf'][green_points], plotname['sigmapsf'][green_points], c='green', fmt='o')

nd_red_points = non_detection['fid']==2
nd_green_points = non_detection['fid']==1
plt.errorbar(non_detection['mjd'][nd_red_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_red_points], c='red', fmt='v')
plt.errorbar(non_detection['mjd'][nd_green_points]-plotname['mjd'][0], non_detection['diffmaglim'][nd_green_points], c='green', fmt='v')

plt.xlabel("Days")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis()

# %%
# plot for red filter
plotname = ET_4

red_points = plotname['fid']==2
x_vals = plotname['mjd'][red_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][red_points]

nd_x_vals = non_detection['mjd'][nd_red_points]-plotname['mjd'][0]
nd_y_vals = non_detection['diffmaglim'][nd_red_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax1 = plt.subplot(2,1,1)
ax1.plot(time, slope, marker='o', color='red')

# Adding text to plot
ax1.set_xlabel("Days")
ax1.set_ylabel(f'Change in Magnitude \n red filter')

plt.title('ZTF20abfhyil')


# plot for green filter


green_points = plotname['fid']==1
x_vals = plotname['mjd'][green_points]-plotname['mjd'][0]
y_vals = plotname['magpsf'][green_points]

nd_x_vals = non_detection['mjd'][nd_green_points]-plotname['mjd'][0]
nd_y_vals = non_detection['diffmaglim'][nd_green_points]

# defining start and end
start = 0
finish = 50
x_vals = x_vals[start:finish]
y_vals = y_vals[start:finish]
y_error = y_error[start:finish]

y_vals = np.array(y_vals)
x_vals = np.array(x_vals)

# include non-detections
x_sorted, y_sorted = include_nd(y_vals, x_vals, nd_y_vals, nd_x_vals)

# finding points to graph
slope, time = find_derivative(x_sorted, y_sorted)

# plot formatting
plt.figure(dpi=150)
ax2 = plt.subplot(2,1,2)
ax2.plot(time, slope, marker='o', color='green')

ax2.set_xlabel("Days")
ax2.set_ylabel(f'Change in Magnitude \n green filter')

#formatting axes
ax1.get_shared_x_axes().join(ax1,ax2)
ax1.get_shared_y_axes().join(ax1,ax2)
plt.show()
